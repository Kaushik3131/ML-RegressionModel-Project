# %%
import sys
from pathlib import Path

# Force notebook to recognize project root
import os
ROOT = Path(os.getcwd()).resolve().parents[0] # one level up from tests/
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

import pandas as pd
from src.inference_pipeline.inference import predict

# Load a few rows of already preprocessed data
sample_path = ROOT / "data/processed/cleaning_eval.csv"
df = pd.read_csv(sample_path).sample(5, random_state=42).reset_index(drop=True)

print("Input sample:")
display(df.head())

# Run inference
preds_df = predict(df)
print("✅ Predictions returned")
display(preds_df[["predicted_price"]].head())
# Out:
# 📂 Inference using project root: E:\ML-projects\Regression_ML_EndtoEnd
# Input sample:
#          date  median_sale_price  median_list_price  median_ppsf  \
# 0  2020-04-30           208250.0           209950.0   138.516484
# 1  2020-08-31           440000.0           459900.0   243.082359
# 2  2021-06-30           152000.0           269000.0   129.251701
# 3  2020-07-31           980000.0           970000.0   371.859296
# 4  2020-09-30           254000.0           239950.0   122.577446
#
#    median_list_ppsf  homes_sold  pending_sales  new_listings  inventory  \
# 0        144.229660       156.0          184.0         200.0      118.0
# 1        247.957301       217.0          253.0         303.0      178.0
# 2        142.794486         5.0            5.0           5.0        2.0
# 3        367.657993        23.0           29.0          29.0        7.0
# 4        129.431457       168.0            0.0         166.0      113.0
#
#    median_dom  ...  Total Labor Force  Unemployed Population  \
# 0        25.0  ...            22946.0                  827.0
# 1        23.0  ...            18857.0                  552.0
# 2        35.0  ...             1609.0                  224.0
# 3        16.0  ...             3705.0                  139.0
# 4        47.0  ...            19112.0                 1065.0
#
#    Total School Age Population Total School Enrollment  Median Commute Time  \
# 0                      38784.0                 38784.0              20782.0
# 1                      36210.0                 36210.0              16738.0
# 2                       3175.0                  3175.0               1324.0
# 3                       6739.0                  6739.0               3012.0
# 4                      34067.0                 34067.0              16684.0
#
#            price                  city_full                  city_norm  \
# 0  215177.598844   Chicago-Naperville-Elgin   Chicago-Naperville-Elgin
# 1  409283.507992   Chicago-Naperville-Elgin   Chicago-Naperville-Elgin
# 2  165245.809142  Orlando-Kissimmee-Sanford  Orlando-Kissimmee-Sanford
# 3  766596.834055    Seattle-Tacoma-Bellevue    Seattle-Tacoma-Bellevue
# 4  234701.594344                  St. Louis                  St. Louis
#
#        lat       lng
# 0  41.6675  -87.9597
# 1  41.6675  -87.9597
# 2  28.4343  -81.3630
# 3  47.5574 -121.8506
# 4  38.7352  -90.3501
#
# [5 rows x 42 columns]
# ⚠️ Skipping lat/lng merge: already present in DataFrame.
# ✅ Dropped 0 duplicate rows (excluding date/year).
# ✅ Removed 0 rows with median_list_price > 19M.
# ✅ Predictions returned
#    predicted_price
# 0     287556.06250
# 1     477852.43750
# 2     282707.96875
# 3     911695.81250
# 4     310103.78125
